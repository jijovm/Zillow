# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Read the formatted file
merged_df = pd.read_csv('formatted_data/train_prop_merged_2016.csv')

# %%
merged_df.head(5)
# Out:
#    parcelid  logerror transactiondate  airconditioningtypeid  \
# 0  11016594    0.0276      2016-01-01                    1.0
# 1  14366692   -0.1684      2016-01-01                    NaN
# 2  12098116   -0.0040      2016-01-01                    1.0
# 3  12643413    0.0218      2016-01-02                    1.0
# 4  14432541   -0.0050      2016-01-02                    NaN
#
#    architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                       NaN           NaN          2.0         3.0
# 1                       NaN           NaN          3.5         4.0
# 2                       NaN           NaN          3.0         2.0
# 3                       NaN           NaN          2.0         2.0
# 4                       NaN           NaN          2.5         4.0
#
#    buildingclasstypeid  buildingqualitytypeid         ...           \
# 0                  NaN                    4.0         ...
# 1                  NaN                    NaN         ...
# ...

# %%
merged_df.shape
# Out:
# (90275, 60)

# %%
merged_df.dtypes['transactiondate']
# Out:
# dtype('O')

# %%
#convert the datatype of transaction date to date and build histogram to see the 
#distribution
pd.to_datetime(merged_df.transactiondate).hist()

# %%
#checking if there are any duplicate records on parcel ids
duplicate_df = merged_df[merged_df['parcelid'].duplicated(keep=False)]

# %%
#number of duplicate records 
print(duplicate_df.shape)
duplicate_df.head(10)
# Out:
# (249, 60)
#       parcelid  logerror transactiondate  airconditioningtypeid  \
# 496   13850164   -0.1567      2016-01-05                   13.0
# 497   13850164   -0.0460      2016-06-29                   13.0
# 781   14677191   -0.3682      2016-01-06                    1.0
# 782   14677191   -0.0845      2016-09-12                    1.0
# 813   11005771   -0.0131      2016-01-06                    NaN
# 814   11005771    0.0545      2016-06-17                    NaN
# 967   11183209   -0.0481      2016-01-07                    1.0
# 968   11183209   -0.0070      2016-09-14                    1.0
# 1164  11554091   -0.1696      2016-01-07                    NaN
# 1165  11554091   -0.0954      2016-07-05                    NaN
#
#       architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 496                        NaN           NaN          2.0         3.0
# 497                        NaN           NaN          2.0         3.0
# ...

# %% [markdown]
# The duplicate records are with different tracsaction date. We are keeping only the latest
# records

# %%
#sort the records by parcel id and transaction date
unique_df = merged_df.sort_values(by=['parcelid','transactiondate'],ascending=False)

# %%
# Remove duplicate records
unique_df.drop_duplicates(subset='parcelid',keep='first',inplace=True)

# %% [markdown]
# Checking null values

# %%
unique_df.isnull().sum().sort_values(ascending=False)
# Out:
# buildingclasstypeid             90134
# finishedsquarefeet13            90117
# basementsqft                    90107
# storytypeid                     90107
# yardbuildingsqft26              90055
# fireplaceflag                   89930
# architecturalstyletypeid        89890
# typeconstructiontypeid          89852
# finishedsquarefeet6             89731
# decktypeid                      89492
# poolsizesum                     89184
# pooltypeid10                    88991
# pooltypeid2                     88946
# taxdelinquencyyear              88375
# taxdelinquencyflag              88375
# hashottuborspa                  87787
# yardbuildingsqft17              87505
# finishedsquarefeet15            86595
# finishedsquarefeet50            83300
# finishedfloor1squarefeet        83300
# fireplacecnt                    80553
# threequarterbathnbr             78154
# pooltypeid7                     73478
# poolcnt                         72274
# numberofstories                 69610
# ...

# %% [markdown]
# Check for columns with all same value - this might not be very useful
# Check discrete columns with high cardinality

# %%
unique_df.nunique().sort_values(ascending=True)
# Out:
# poolcnt                             1
# storytypeid                         1
# fireplaceflag                       1
# pooltypeid7                         1
# pooltypeid2                         1
# buildingclasstypeid                 1
# pooltypeid10                        1
# assessmentyear                      1
# decktypeid                          1
# taxdelinquencyflag                  1
# hashottuborspa                      1
# typeconstructiontypeid              3
# regionidcounty                      3
# fips                                3
# threequarterbathnbr                 4
# numberofstories                     4
# fireplacecnt                        5
# airconditioningtypeid               6
# architecturalstyletypeid            6
# buildingqualitytypeid               8
# unitcnt                            10
# finishedsquarefeet13               11
# taxdelinquencyyear                 11
# heatingorsystemtypeid              12
# fullbathcnt                        14
# ...

# %%
#check target variable distribution
unique_df.logerror.hist()
